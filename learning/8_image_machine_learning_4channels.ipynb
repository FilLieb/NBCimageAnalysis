# %% [markdown]
# # image segmentation in python using pixel classification for all 4 channels
# a notebook to learn image segmentation using labeled images

# %% [markdown]
# in Colab, we need to connect to a GPU

# %% [markdown]
# on the to right, go to change runtime type and select T4 GPU

# %%
pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (0.26.0)
# Requirement already satisfied: numpy>=1.24 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from scikit-image) (2.4.4)
# Requirement already satisfied: scipy>=1.11.4 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from scikit-image) (1.17.1)
# Requirement already satisfied: networkx>=3.0 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from scikit-image) (3.6.1)
# Requirement already satisfied: pillow>=10.1 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from scikit-image) (12.2.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from scikit-image) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from scikit-image) (2026.5.2)
# Requirement already satisfied: packaging>=21 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from scikit-image) (26.2)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from scikit-image) (0.5)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from matplotlib) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install apoc --no-deps
# !pip install "scikit-learn" "pyclesperanto-prototype" "pandas" "numpy==2.4.4"
# Out:
# Requirement already satisfied: apoc in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (0.12.0)
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scikit-learn in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (1.8.0)
# Requirement already satisfied: pyclesperanto-prototype in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (0.24.4)
# Requirement already satisfied: pandas in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (3.0.2)
# Requirement already satisfied: numpy==2.4.4 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (2.4.4)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: pyopencl in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from pyclesperanto-prototype) (2026.1.2)
# Requirement already satisfied: toolz in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from pyclesperanto-prototype) (1.1.0)
# Requirement already satisfied: scikit-image!=0.20.0,>=0.18.0 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from pyclesperanto-prototype) (0.26.0)
# Requirement already satisfied: matplotlib in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from pyclesperanto-prototype) (3.10.9)
# Requirement already satisfied: transforms3d in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from pyclesperanto-prototype) (0.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from scikit-image!=0.20.0,>=0.18.0->pyclesperanto-prototype) (3.6.1)
# Requirement already satisfied: pillow>=10.1 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from scikit-image!=0.20.0,>=0.18.0->pyclesperanto-prototype) (12.2.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from scikit-image!=0.20.0,>=0.18.0->pyclesperanto-prototype) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from scikit-image!=0.20.0,>=0.18.0->pyclesperanto-prototype) (2026.5.2)
# Requirement already satisfied: packaging>=21 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from scikit-image!=0.20.0,>=0.18.0->pyclesperanto-prototype) (26.2)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from scikit-image!=0.20.0,>=0.18.0->pyclesperanto-prototype) (0.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from matplotlib->pyclesperanto-prototype) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from matplotlib->pyclesperanto-prototype) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from matplotlib->pyclesperanto-prototype) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from matplotlib->pyclesperanto-prototype) (1.5.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from matplotlib->pyclesperanto-prototype) (3.3.2)
# Requirement already satisfied: platformdirs>=2.2 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from pyopencl->pyclesperanto-prototype) (4.9.6)
# Requirement already satisfied: pytools>=2025.1.6 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from pyopencl->pyclesperanto-prototype) (2026.1)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from pyopencl->pyclesperanto-prototype) (4.15.0)
# Requirement already satisfied: siphash24>=1.6 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from pytools>=2025.1.6->pyopencl->pyclesperanto-prototype) (1.8)
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from matplotlib import pyplot as plt
import apoc
from skimage.io import imread, imsave
import numpy as np

# %%
import os
# Clone the repo if not already in Colab
if 'google.colab' in str(get_ipython()):
    if not os.path.exists('/content/NBCimageAnalysis'):
        # !git clone https://github.com/FilLieb/NBCimageAnalysis.git
    os.chdir('/content/NBCimageAnalysis/learning/')
    print(os.listdir('.'))

# %% [markdown]
# We have 4 channels and assign their names to a list:

# %%
channels = ["DAAO", "Cre", "vGAT", "Gphn"]  # change index to switch between channels

# %% [markdown]
# let's check that is all correct...

# %%
for channel in channels: 
    image_folder = '../training_4_channels/' + channel + '/images/'
    masks_folder = '../training_4_channels/' + channel + '/masks/'

    image_path = os.path.join(image_folder, os.listdir(image_folder)[0])
    image = imread(image_path)

    masks_path = os.path.join(masks_folder, os.listdir(masks_folder)[0])
    masks = imread(masks_path)


    f, a = plt.subplots(1,3, figsize=(15,5))
    a[0].imshow(image, cmap='gray')
    a[0].set_title("Image" + channel)

    a[1].imshow(masks, vmin=0, vmax=2)
    a[1].set_title("Masks" + channel)

    a[2].imshow(image, cmap='gray')
    a[2].contour(masks, colors='r', linewidths=0.5)
    a[2].set_title("Overlay" + channel)

plt.show()

# %% [markdown]
# we can now loop through this list to train all models...

# %%
for channel in channels: 
    image_folder = '../training_4_channels/' + channel + '/images/'
    masks_folder = '../training_4_channels/' + channel + '/masks/'

     # this is where the model will be saved
    cl_filename = '../training_4_channels/' + channel + '/models/' + channel + '_object_model.cl'
    
    apoc.erase_classifier(cl_filename) # delete it if it was existing before

    # setup classifier and where it should be saved
    segmenter = apoc.ObjectSegmenter(opencl_filename=cl_filename,
                                     max_depth=5,
                                     num_ensembles=1000)

    # setup feature set used for training
    features = apoc.PredefinedFeatureSet.small_dog_log.value + " " + \
               apoc.PredefinedFeatureSet.medium_dog_log.value + " " + \
               apoc.PredefinedFeatureSet.large_dog_log.value

    # train classifier on folders
    apoc.erase_classifier(cl_filename)
    apoc.train_classifier_from_image_folders(
        segmenter,
        features,
        image = image_folder,
        ground_truth = masks_folder)
    
    print("Training completed and model saved to " + cl_filename)
# Out:
# Training completed and model saved to ../training_4_channels/DAAO/models/DAAO_object_model.cl
# Training completed and model saved to ../training_4_channels/Cre/models/Cre_object_model.cl
# Training completed and model saved to ../training_4_channels/vGAT/models/vGAT_object_model.cl
# Training completed and model saved to ../training_4_channels/Gphn/models/Gphn_object_model.cl

# %% [markdown]
# finally we can test how the model performed

# %%
for channel in channels: 
    image_folder = '../training_4_channels/' + channel + '/images/'

    image_path = os.path.join(image_folder, os.listdir(image_folder)[0])
    image = imread(image_path)

    segmenter = apoc.ObjectSegmenter(opencl_filename=cl_filename)
    labels = segmenter.predict(image)

    f, a = plt.subplots(1,3, figsize=(15,5))
    a[0].imshow(image, cmap='gray')
    a[0].set_title("Image" + channel)

    a[1].imshow(labels, vmin=0, vmax=2)
    a[1].set_title("Labels" + channel)

    a[2].imshow(image, cmap='gray')
    a[2].contour(labels, colors='r', linewidths=0.5)
    a[2].set_title("Overlay" + channel)

plt.show()

# %% [markdown]
# Now we can put things together and run our models on multiple images...

# %%
pip install readlif
# Out:
# Requirement already satisfied: readlif in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (0.6.6)
# Requirement already satisfied: beautifulsoup4>=4.12.3 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from readlif) (4.14.3)
# Requirement already satisfied: numpy>=2.0.0 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from readlif) (2.4.4)
# Requirement already satisfied: pillow>=7.2.0 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from readlif) (12.2.0)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from beautifulsoup4>=4.12.3->readlif) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from beautifulsoup4>=4.12.3->readlif) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from readlif.reader import LifFile

# %%
# set paths
image_folder = '../data/2026group2/'

# %%
def execute(file, root):
    print(f"Found image: {file}")
    folder_name = os.path.splitext(os.path.basename(file))[0] # removes the .lif extension
    folder_path = os.path.join(root, folder_name)
    os.makedirs(folder_path, exist_ok=True)

    lif = LifFile(file)

    for img in lif.get_iter_image():
        print(img.name, img.dims)
        channels_array = np.stack([np.array(channel) for channel in img.get_iter_c(t=0, z=0)])
        make_masks("DAAO", channels_array[0], folder_path, img.name)
        make_masks("vGAT", channels_array[1], folder_path, img.name)
        make_masks("Cre", channels_array[2], folder_path, img.name)
        make_masks("Gphn", channels_array[3], folder_path, img.name)

# %%
# make mask per channel
def make_masks(channel, array, path, image):
    print("Generating masks...")

    out_file = os.path.join(path, image + '_' + channel + '_labels.tif')
    
    cl_filename = '../training_4_channels/' + channel + '/models/' + channel + '_object_model.cl'
    segmenter = apoc.ObjectSegmenter(opencl_filename=cl_filename)
    labels = segmenter.predict(array)

    imsave(out_file, labels)

# %%
for root, dirs, files in os.walk(image_folder):
    for file in files:
        if file.endswith("High Density.lif"):
            full_path = os.path.join(root, file)
            print(full_path)
            execute(full_path, root)

print("...completed.")
# Out:
# ../data/2026group2/Gruppe2 WT + DMet High Density.lif
# Found image: ../data/2026group2/Gruppe2 WT + DMet High Density.lif
# Image 1 Dims(x=1024, y=1024, z=1, t=1, m=1)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT + DMet High Density\Image 1_DAAO_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT + DMet High Density\Image 1_vGAT_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT + DMet High Density\Image 1_Cre_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT + DMet High Density\Image 1_Gphn_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Image 2 Dims(x=1024, y=1024, z=1, t=1, m=1)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT + DMet High Density\Image 2_DAAO_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT + DMet High Density\Image 2_vGAT_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT + DMet High Density\Image 2_Cre_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT + DMet High Density\Image 2_Gphn_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Image 3 Dims(x=1024, y=1024, z=1, t=1, m=1)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT + DMet High Density\Image 3_DAAO_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT + DMet High Density\Image 3_vGAT_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT + DMet High Density\Image 3_Cre_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT + DMet High Density\Image 3_Gphn_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Image 4 Dims(x=1024, y=1024, z=1, t=1, m=1)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT + DMet High Density\Image 4_DAAO_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT + DMet High Density\Image 4_vGAT_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT + DMet High Density\Image 4_Cre_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT + DMet High Density\Image 4_Gphn_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Image 5 Dims(x=1024, y=1024, z=1, t=1, m=1)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT + DMet High Density\Image 5_DAAO_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT + DMet High Density\Image 5_vGAT_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT + DMet High Density\Image 5_Cre_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT + DMet High Density\Image 5_Gphn_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# ../data/2026group2/Gruppe2 WT - DMet High Density.lif
# Found image: ../data/2026group2/Gruppe2 WT - DMet High Density.lif
# Image 1 Dims(x=1024, y=1024, z=1, t=1, m=1)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT - DMet High Density\Image 1_DAAO_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT - DMet High Density\Image 1_vGAT_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT - DMet High Density\Image 1_Cre_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT - DMet High Density\Image 1_Gphn_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Image 2 Dims(x=1024, y=1024, z=1, t=1, m=1)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT - DMet High Density\Image 2_DAAO_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT - DMet High Density\Image 2_vGAT_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT - DMet High Density\Image 2_Cre_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT - DMet High Density\Image 2_Gphn_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Image 3 Dims(x=1024, y=1024, z=1, t=1, m=1)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT - DMet High Density\Image 3_DAAO_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT - DMet High Density\Image 3_vGAT_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT - DMet High Density\Image 3_Cre_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT - DMet High Density\Image 3_Gphn_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Image 4 Dims(x=1024, y=1024, z=1, t=1, m=1)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT - DMet High Density\Image 4_DAAO_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT - DMet High Density\Image 4_vGAT_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT - DMet High Density\Image 4_Cre_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT - DMet High Density\Image 4_Gphn_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Image 5 Dims(x=1024, y=1024, z=1, t=1, m=1)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT - DMet High Density\Image 5_DAAO_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT - DMet High Density\Image 5_vGAT_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Generating masks...
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT - DMet High Density\Image 5_Cre_labels.tif is a low contrast image
#   return func(*args, **kwargs)
# Generating masks...
# ...completed.
# c:\Users\liebs\VSCodeProjects\NBCimageAnalysis\.venv-1\Lib\site-packages\skimage\_shared\utils.py:386: UserWarning: ../data/2026group2/Gruppe2 WT - DMet High Density\Image 5_Gphn_labels.tif is a low contrast image
#   return func(*args, **kwargs)

# %%
for root, dirs, files in os.walk(image_folder):
    for file in files:
        if file.endswith("_labels.tif"):
            label_path = os.path.join(root, file)
            label = imread(label_path)
            plt.figure()
            plt.imshow(label)
            plt.title("predicted labels: " + file)
            plt.show()
