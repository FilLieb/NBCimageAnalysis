# %% [markdown]
# # Loading and Displaying Images into python
# a notebook for basic image loading and display.

# %% [markdown]
# to work with images, we will use packages that need to be installed

# %%
pip install scikit-image
# Out:
# Collecting scikit-image
#   Downloading scikit_image-0.26.0-cp313-cp313-win_amd64.whl.metadata (15 kB)
# Collecting numpy>=1.24 (from scikit-image)
#   Downloading numpy-2.4.4-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# Collecting scipy>=1.11.4 (from scikit-image)
#   Downloading scipy-1.17.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting networkx>=3.0 (from scikit-image)
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting pillow>=10.1 (from scikit-image)
#   Downloading pillow-12.2.0-cp313-cp313-win_amd64.whl.metadata (9.0 kB)
# Collecting imageio!=2.35.0,>=2.33 (from scikit-image)
#   Downloading imageio-2.37.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image)
#   Downloading tifffile-2026.5.2-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: packaging>=21 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from scikit-image) (26.2)
# Collecting lazy-loader>=0.4 (from scikit-image)
#   Downloading lazy_loader-0.5-py3-none-any.whl.metadata (5.9 kB)
# Downloading scikit_image-0.26.0-cp313-cp313-win_amd64.whl (11.9 MB)
#    ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.9 MB 2.1 MB/s eta 0:00:06
#    --- ------------------------------------ 1.0/11.9 MB 2.1 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.6/11.9 MB 2.1 MB/s eta 0:00:06
#    ------- -------------------------------- 2.1/11.9 MB 2.1 MB/s eta 0:00:05
#    -------- ------------------------------- 2.6/11.9 MB 2.1 MB/s eta 0:00:05
#    --------- ------------------------------ 2.9/11.9 MB 2.1 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.4/11.9 MB 2.1 MB/s eta 0:00:05
#    ------------- -------------------------- 3.9/11.9 MB 2.0 MB/s eta 0:00:04
#    -------------- ------------------------- 4.2/11.9 MB 2.0 MB/s eta 0:00:04
#    --------------- ------------------------ 4.7/11.9 MB 2.0 MB/s eta 0:00:04
#    ----------------- ---------------------- 5.2/11.9 MB 2.0 MB/s eta 0:00:04
#    ------------------ --------------------- 5.5/11.9 MB 2.0 MB/s eta 0:00:04
#    -------------------- ------------------- 6.0/11.9 MB 2.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.6/11.9 MB 2.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.8/11.9 MB 2.1 MB/s eta 0:00:03
#    ------------------------ --------------- 7.3/11.9 MB 2.1 MB/s eta 0:00:03
#    -------------------------- ------------- 7.9/11.9 MB 2.1 MB/s eta 0:00:02
#    --------------------------- ------------ 8.1/11.9 MB 2.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.7/11.9 MB 2.1 MB/s eta 0:00:02
#    ------------------------------ --------- 9.2/11.9 MB 2.1 MB/s eta 0:00:02
#    ------------------------------- -------- 9.4/11.9 MB 2.1 MB/s eta 0:00:02
#    --------------------------------- ------ 10.0/11.9 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.5/11.9 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 10.7/11.9 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------- -- 11.3/11.9 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  11.8/11.9 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 11.9/11.9 MB 2.0 MB/s eta 0:00:00
# Downloading imageio-2.37.3-py3-none-any.whl (317 kB)
# Downloading lazy_loader-0.5-py3-none-any.whl (8.0 kB)
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Downloading numpy-2.4.4-cp313-cp313-win_amd64.whl (12.3 MB)
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/12.3 MB 2.2 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.3/12.3 MB 2.1 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.6/12.3 MB 2.1 MB/s eta 0:00:06
#    ------ --------------------------------- 2.1/12.3 MB 2.1 MB/s eta 0:00:05
#    -------- ------------------------------- 2.6/12.3 MB 2.1 MB/s eta 0:00:05
#    ---------- ----------------------------- 3.1/12.3 MB 2.1 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.4/12.3 MB 2.1 MB/s eta 0:00:05
#    ------------ --------------------------- 3.9/12.3 MB 2.1 MB/s eta 0:00:05
#    -------------- ------------------------- 4.5/12.3 MB 2.1 MB/s eta 0:00:04
#    ---------------- ----------------------- 5.0/12.3 MB 2.1 MB/s eta 0:00:04
#    ----------------- ---------------------- 5.2/12.3 MB 2.1 MB/s eta 0:00:04
#    ------------------ --------------------- 5.8/12.3 MB 2.1 MB/s eta 0:00:04
#    -------------------- ------------------- 6.3/12.3 MB 2.1 MB/s eta 0:00:03
#    --------------------- ------------------ 6.6/12.3 MB 2.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 7.1/12.3 MB 2.1 MB/s eta 0:00:03
#    ------------------------ --------------- 7.6/12.3 MB 2.1 MB/s eta 0:00:03
#    ------------------------- -------------- 7.9/12.3 MB 2.1 MB/s eta 0:00:03
#    --------------------------- ------------ 8.4/12.3 MB 2.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.9/12.3 MB 2.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.2/12.3 MB 2.1 MB/s eta 0:00:02
#    ------------------------------- -------- 9.7/12.3 MB 2.1 MB/s eta 0:00:02
#    --------------------------------- ------ 10.2/12.3 MB 2.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 10.5/12.3 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.0/12.3 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------- -- 11.5/12.3 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 11.8/12.3 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  12.1/12.3 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 2.0 MB/s eta 0:00:00
# Downloading pillow-12.2.0-cp313-cp313-win_amd64.whl (7.1 MB)
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.8/7.1 MB 2.0 MB/s eta 0:00:04
#    ------- -------------------------------- 1.3/7.1 MB 2.1 MB/s eta 0:00:03
#    -------- ------------------------------- 1.6/7.1 MB 2.1 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.1/7.1 MB 2.1 MB/s eta 0:00:03
#    -------------- ------------------------- 2.6/7.1 MB 2.0 MB/s eta 0:00:03
#    ---------------- ----------------------- 2.9/7.1 MB 2.1 MB/s eta 0:00:03
#    ------------------- -------------------- 3.4/7.1 MB 2.0 MB/s eta 0:00:02
#    -------------------- ------------------- 3.7/7.1 MB 2.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.2/7.1 MB 2.1 MB/s eta 0:00:02
#    -------------------------- ------------- 4.7/7.1 MB 2.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 5.2/7.1 MB 2.1 MB/s eta 0:00:01
#    ------------------------------- -------- 5.5/7.1 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.0/7.1 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.3/7.1 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 6.8/7.1 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 7.1/7.1 MB 2.0 MB/s eta 0:00:00
# Downloading scipy-1.17.1-cp313-cp313-win_amd64.whl (36.5 MB)
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#     --------------------------------------- 0.8/36.5 MB 2.1 MB/s eta 0:00:17
#    - -------------------------------------- 1.0/36.5 MB 2.1 MB/s eta 0:00:17
#    - -------------------------------------- 1.6/36.5 MB 2.0 MB/s eta 0:00:18
#    -- ------------------------------------- 2.1/36.5 MB 2.0 MB/s eta 0:00:18
#    -- ------------------------------------- 2.4/36.5 MB 2.0 MB/s eta 0:00:17
#    --- ------------------------------------ 2.9/36.5 MB 2.0 MB/s eta 0:00:17
#    --- ------------------------------------ 3.4/36.5 MB 2.0 MB/s eta 0:00:17
#    ---- ----------------------------------- 3.7/36.5 MB 2.0 MB/s eta 0:00:17
#    ---- ----------------------------------- 4.2/36.5 MB 2.0 MB/s eta 0:00:16
#    ---- ----------------------------------- 4.5/36.5 MB 2.0 MB/s eta 0:00:16
#    ----- ---------------------------------- 5.0/36.5 MB 2.0 MB/s eta 0:00:16
#    ------ --------------------------------- 5.5/36.5 MB 2.0 MB/s eta 0:00:16
#    ------ --------------------------------- 5.8/36.5 MB 2.0 MB/s eta 0:00:16
#    ------ --------------------------------- 6.3/36.5 MB 2.0 MB/s eta 0:00:16
#    ------- -------------------------------- 6.8/36.5 MB 2.0 MB/s eta 0:00:15
#    ------- -------------------------------- 7.1/36.5 MB 2.0 MB/s eta 0:00:15
#    -------- ------------------------------- 7.6/36.5 MB 2.0 MB/s eta 0:00:15
#    -------- ------------------------------- 8.1/36.5 MB 2.0 MB/s eta 0:00:15
#    --------- ------------------------------ 8.4/36.5 MB 2.0 MB/s eta 0:00:15
#    --------- ------------------------------ 8.9/36.5 MB 2.0 MB/s eta 0:00:14
#    ---------- ----------------------------- 9.2/36.5 MB 2.0 MB/s eta 0:00:14
#    ---------- ----------------------------- 9.7/36.5 MB 2.0 MB/s eta 0:00:14
#    ----------- ---------------------------- 10.2/36.5 MB 2.0 MB/s eta 0:00:14
#    ----------- ---------------------------- 10.5/36.5 MB 2.0 MB/s eta 0:00:13
#    ------------ --------------------------- 11.0/36.5 MB 2.0 MB/s eta 0:00:13
#    ------------ --------------------------- 11.5/36.5 MB 2.0 MB/s eta 0:00:13
#    ------------ --------------------------- 11.8/36.5 MB 2.0 MB/s eta 0:00:13
#    ------------- -------------------------- 12.3/36.5 MB 2.0 MB/s eta 0:00:13
#    ------------- -------------------------- 12.6/36.5 MB 2.0 MB/s eta 0:00:12
#    -------------- ------------------------- 13.1/36.5 MB 2.0 MB/s eta 0:00:12
#    -------------- ------------------------- 13.6/36.5 MB 2.0 MB/s eta 0:00:12
#    --------------- ------------------------ 13.9/36.5 MB 2.0 MB/s eta 0:00:12
#    --------------- ------------------------ 14.4/36.5 MB 2.0 MB/s eta 0:00:12
#    ---------------- ----------------------- 14.7/36.5 MB 2.0 MB/s eta 0:00:11
#    ---------------- ----------------------- 15.2/36.5 MB 2.0 MB/s eta 0:00:11
#    ----------------- ---------------------- 15.7/36.5 MB 2.0 MB/s eta 0:00:11
#    ----------------- ---------------------- 16.3/36.5 MB 2.0 MB/s eta 0:00:11
#    ------------------ --------------------- 16.5/36.5 MB 2.0 MB/s eta 0:00:10
#    ------------------ --------------------- 17.0/36.5 MB 2.0 MB/s eta 0:00:10
#    ------------------- -------------------- 17.6/36.5 MB 2.0 MB/s eta 0:00:10
#    ------------------- -------------------- 17.8/36.5 MB 2.0 MB/s eta 0:00:10
#    -------------------- ------------------- 18.4/36.5 MB 2.0 MB/s eta 0:00:10
#    -------------------- ------------------- 18.9/36.5 MB 2.0 MB/s eta 0:00:09
#    -------------------- ------------------- 19.1/36.5 MB 2.0 MB/s eta 0:00:09
#    --------------------- ------------------ 19.7/36.5 MB 2.0 MB/s eta 0:00:09
#    ---------------------- ----------------- 20.2/36.5 MB 2.0 MB/s eta 0:00:09
#    ---------------------- ----------------- 20.4/36.5 MB 2.0 MB/s eta 0:00:08
#    ---------------------- ----------------- 21.0/36.5 MB 2.0 MB/s eta 0:00:08
#    ----------------------- ---------------- 21.5/36.5 MB 2.0 MB/s eta 0:00:08
#    ----------------------- ---------------- 21.8/36.5 MB 2.0 MB/s eta 0:00:08
#    ------------------------ --------------- 22.3/36.5 MB 2.0 MB/s eta 0:00:08
#    ------------------------ --------------- 22.8/36.5 MB 2.0 MB/s eta 0:00:07
#    ------------------------- -------------- 23.1/36.5 MB 2.0 MB/s eta 0:00:07
#    ------------------------- -------------- 23.6/36.5 MB 2.0 MB/s eta 0:00:07
#    -------------------------- ------------- 24.1/36.5 MB 2.0 MB/s eta 0:00:07
#    -------------------------- ------------- 24.4/36.5 MB 2.0 MB/s eta 0:00:06
#    --------------------------- ------------ 24.9/36.5 MB 2.0 MB/s eta 0:00:06
#    --------------------------- ------------ 25.4/36.5 MB 2.0 MB/s eta 0:00:06
#    ---------------------------- ----------- 25.7/36.5 MB 2.0 MB/s eta 0:00:06
#    ---------------------------- ----------- 26.2/36.5 MB 2.0 MB/s eta 0:00:06
#    ----------------------------- ---------- 26.7/36.5 MB 2.0 MB/s eta 0:00:05
#    ----------------------------- ---------- 27.0/36.5 MB 2.0 MB/s eta 0:00:05
#    ------------------------------ --------- 27.5/36.5 MB 2.0 MB/s eta 0:00:05
#    ------------------------------ --------- 28.0/36.5 MB 2.0 MB/s eta 0:00:05
#    ------------------------------- -------- 28.3/36.5 MB 2.0 MB/s eta 0:00:05
#    ------------------------------- -------- 28.8/36.5 MB 2.0 MB/s eta 0:00:04
#    -------------------------------- ------- 29.4/36.5 MB 2.0 MB/s eta 0:00:04
#    -------------------------------- ------- 29.6/36.5 MB 2.0 MB/s eta 0:00:04
#    --------------------------------- ------ 30.1/36.5 MB 2.0 MB/s eta 0:00:04
#    --------------------------------- ------ 30.7/36.5 MB 2.0 MB/s eta 0:00:03
#    --------------------------------- ------ 30.9/36.5 MB 2.0 MB/s eta 0:00:03
#    ---------------------------------- ----- 31.5/36.5 MB 2.0 MB/s eta 0:00:03
#    ----------------------------------- ---- 32.0/36.5 MB 2.0 MB/s eta 0:00:03
#    ----------------------------------- ---- 32.2/36.5 MB 2.0 MB/s eta 0:00:03
#    ----------------------------------- ---- 32.8/36.5 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------ --- 33.0/36.5 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------ --- 33.6/36.5 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------- -- 33.8/36.5 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------- -- 34.3/36.5 MB 2.0 MB/s eta 0:00:02
#    -------------------------------------- - 34.9/36.5 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 35.1/36.5 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  35.7/36.5 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  36.2/36.5 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  36.4/36.5 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  36.4/36.5 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 36.5/36.5 MB 2.0 MB/s eta 0:00:00
# Downloading tifffile-2026.5.2-py3-none-any.whl (266 kB)
# Installing collected packages: pillow, numpy, networkx, lazy-loader, tifffile, scipy, imageio, scikit-image
# Successfully installed imageio-2.37.3 lazy-loader-0.5 networkx-3.6.1 numpy-2.4.4 pillow-12.2.0 scikit-image-0.26.0 scipy-1.17.1 tifffile-2026.5.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.9-cp313-cp313-win_amd64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.1-cp313-cp313-win_amd64.whl.metadata (119 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp313-cp313-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from matplotlib) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from matplotlib) (12.2.0)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\liebs\vscodeprojects\nbcimageanalysis\.venv-1\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.9-cp313-cp313-win_amd64.whl (8.2 MB)
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.2 MB 2.2 MB/s eta 0:00:04
#    ------ --------------------------------- 1.3/8.2 MB 2.1 MB/s eta 0:00:04
#    ------- -------------------------------- 1.6/8.2 MB 2.1 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.1/8.2 MB 2.1 MB/s eta 0:00:03
#    ------------ --------------------------- 2.6/8.2 MB 2.1 MB/s eta 0:00:03
#    --------------- ------------------------ 3.1/8.2 MB 2.1 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.4/8.2 MB 2.1 MB/s eta 0:00:03
#    ------------------- -------------------- 3.9/8.2 MB 2.1 MB/s eta 0:00:03
#    --------------------- ------------------ 4.5/8.2 MB 2.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.7/8.2 MB 2.1 MB/s eta 0:00:02
#    ------------------------- -------------- 5.2/8.2 MB 2.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.8/8.2 MB 2.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.0/8.2 MB 2.1 MB/s eta 0:00:02
#    ------------------------------- -------- 6.6/8.2 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.1/8.2 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.3/8.2 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.2 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.2 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 2.0 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp313-cp313-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB 2.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.3/2.3 MB 2.1 MB/s eta 0:00:01
#    -------------------------- ------------- 1.6/2.3 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.1/2.3 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 2.0 MB/s eta 0:00:00
# Downloading kiwisolver-1.5.0-cp313-cp313-win_amd64.whl (73 kB)
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.9 pyparsing-3.3.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# next we will import the packages that we need, with "import" entire packages can be used, with "from ... import" parts can be used and with "...as" we can define an acronym to be used for functions from the package

# %%
import os
from skimage.io import imread
import matplotlib.pyplot as plt

# %%
# Clone the repo if not already in Colab
if 'google.colab' in str(get_ipython()):
    if not os.path.exists('/content/NBCimageAnalysis'):
        # !git clone https://github.com/FilLieb/NBCimageAnalysis.git
    os.chdir('/content/NBCimageAnalysis/learning/')
    print(os.listdir('.'))

# %% [markdown]
# ## Load and Display an Image
# Loading a sample image and displaying it using matplotlib

# %%
img = imread('../data/artificial/test_3col.tif')
data = img  # imread returns the image data directly
data.shape
# Out:
# (1500, 1500, 3)

# %% [markdown]
# ## Image Basics
# display channels of an image

# %%
# Extract each channel slice (assume 3 channels, for example)
channel_0 = data[:, :, 0]
channel_1 = data[:, :, 1]
channel_2 = data[:, :, 2]

# make a quick figure to display individual channels
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].imshow(channel_0, cmap='gray')
axes[0].set_title("Channel 0")

axes[1].imshow(channel_1, cmap='gray')
axes[1].set_title("Channel 1")

axes[2].imshow(channel_2, cmap='gray')
axes[2].set_title("Channel 2")

plt.tight_layout()
plt.show()
